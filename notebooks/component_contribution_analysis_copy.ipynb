# %% [markdown]
# # Component contribution analysis
#
# From the hyperparameter tuning step, we have selected a set of parameters ($\lambda$,  $ \vartheta$, k) with largest **LLPD$_o$**.
#
# Here we aim to evaluate the contribution of each of the components in the generative model (MEM). The generative model for the ocean microbiome data for the microbial abundance data consists of **geochemical component**, **spatio-temporal components indicating geographical location, ocean depth and time** and **species-species interaction component**. To understand their  contribution in the MEM, we drop each of the specific component in the generative model, estimate the variational posterior and then evaluate the model performance in terms of the **out of sample log-likelihood predictive density (LLPD$_o$)**.
#
#
# Steps of the analysis
#  + Define component excluded generative model
#  + Python script for the variational posterior estimation: **component_contribution_fit.py**
#  + Script to call component excluded generative model
#  + Evaluate the model in terms of the **LLPD$_o$**
#
#
# #### Component excluded generative model
# We have defined the component excluded stan model (see stan_model folder) in the following files:
#  + **NB_microbe_ppc.stan** : Full model [Model = 0]
#  + **NB_microbe_ppc-1.stan** : Province component dropped  [Model = 1]
#  + **NB_microbe_ppc-2.stan** : Biome component dropped  [Model = 2]
#  + **NB_microbe_ppc-3.stan** : Quarter/Time component dropped  [Model = 3]
#  + **NB_microbe_ppc-G.stan** : Geochemical component dropped  [Model = 4]
#  + **NB_microbe_ppc_nointer.stan** : Species-species interaction component dropped  [Model = 5]

# %% [markdown]
# #### Script to evaluate the model
# For the chosen set of hyperparameters, we compute the variational posterior of each the **component excluded generative model** for **twenty** different initialization. We have saved the command calling **component_contribution_fit.py** for each of the  **component excluded generative model** in the file **mem_component_contribution** (see the python cript below to generate the file).
#
# A line in the file **mem_component_contribution** calls the python script **component_contribution_fit.py** for a given choice of the parameters.
#
# *module purge ; module load slurm gcc python3 ; OMP_NUM_THREADS=1 python3 component_contribution_fit.py 100.0 0.219 0.06503 0.1 200 1 0 1.0 > logfile/1.log 2>&1*
#
# Input parameters for a setting includes **latent rank (k),  $\lambda$,  $\vartheta$, test sample proportion, variational posterior sample size,  sub-settings unique ID (1-20), model type  and setting seed**.

# %% [raw]
# import os
# import numpy as np
# import random
# import pickle as pkl
# random.seed(123)
# best_model_param = pkl.load(open('selected_hyperparam', 'rb'))
# best_model_param = [best_model_param['k'].values[0],\
#                     best_model_param['lambda'].values[0],\
#                     best_model_param['upsilon'].values[0]]
# h_prop = 0.1    # holdout proportion of test sample data to compute LLPD
# nsample_o = 200 # number of posterior sample
#
# # command for server
# command_server = 'module purge ; module load slurm gcc python3 ; OMP_NUM_THREADS=1 python3 component_contribution_fit.py '
# setting = []
# seedid = 0. ;
#
# # generates setting and corresponding command script
# # mtype: variable for 6 model type including full model
# for mtype in range(6):
#     for sid in range(20):
#         seedid = seedid + 1.
#         a = command_server + ' '.join(list(map(str,   best_model_param + [h_prop, nsample_o, sid + 1,mtype, seedid] )))
#         setting.append((a + ' > logfile/{}.log 2>&1').format(int(seedid)))
#
# # save command
# fname = "mem_component_contribution"
# with open(fname, 'w') as filehandle:
#     filehandle.writelines("%s\n" % place for place in setting)

# %% [markdown]
# #### Parameter estimation
# We run the script on server using the command:
# *sbatch -N [#node] -p [#partition] disBatch.py -t [#task on each node] [script_file]*
# Example: *sbatch -N 10 -p ccm disBatch.py -t 25 mem_component_contribution*
#
#
#
#
# #### Model output analysis
# Evaluate each of the **component excluded generative model** based on the $LLPD_o$. Let us consider our model output is saved in the folder **CContribution**. To compare the model, we load the output file and compute the $LLPD_o$ for each model.

# %%
## Load all the required python module for the analysis 
import glob 
import pickle as pkl
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import hiplot as hip
import os 
import copy 
# %matplotlib inline

# 1. Read config_mode.txt
config_file = "config_mode.txt"
if os.path.exists(config_file):
    with open(config_file, "r") as f:
        lines = f.read().splitlines()
        data = lines[0].strip() if len(lines) > 0 else "original"
        setting = int(lines[1]) if len(lines) > 1 else 1


# 2. Set plots folder based on config
if data == "original" and setting == 1: 
    figfol = "./plots1/"
elif data == "original" and setting == 2:
    figfol = "./plots2/"
elif data == "new" and setting == 2: 
    figfol = "./plots3/"
elif data == "new" and setting == 1: 
    figfol = "./plots4/"

if not os.path.exists(figfol):
    os.makedirs(figfol)
    print(f"✅ Created folder: {figfol}")
else:
    print(f"📂 Folder already exists: {figfol}")

if data == "original" and setting == 1:
    fname_o = glob.glob('../results/results_old_c/component/models/extracted/*model_nb_cvtest.pkl')
elif data == "original" and setting ==2: 
    fname_o = glob.glob('../results/results_old_nc/component/models/*model_nb_cvtest.pkl') 
elif data =="new" and setting ==2: 
    fname_o = glob.glob('../results/results_new_var_nc/component/models/*model_nb_cvtest.pkl') 
elif data =="new" and setting ==1: 
    fname_o = glob.glob('../results/results_new_var_c/component/models/*model_nb_cvtest.pkl') 
print("Loaded files (first 10):", fname_o[:10])
print("Loaded files (first 10):", fname_o[:10])
# Out:
# 📂 Folder already exists: ./plots4/
# Loaded files (first 10): ['../results/results_new_var_c/component/models/30_11_17_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_8_13_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_8_3_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_7_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_16_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_11_20_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_10_19_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_12_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_10_1_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_3_model_nb_cvtest.pkl']
# Loaded files (first 10): ['../results/results_new_var_c/component/models/30_11_17_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_8_13_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_8_3_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_7_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_16_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_11_20_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_10_19_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_12_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_10_1_model_nb_cvtest.pkl', '../results/results_new_var_c/component/models/30_12_3_model_nb_cvtest.pkl']

# %%
# Already defined earlier:
# fname_o = glob.glob(...) → a list of model file paths

model_files = fname_o  # Already globbed earlier
print(f"✅ Found {len(model_files)} model files.")

# Extract model data
model_data = []

for model_file in model_files:
    with open(model_file, "rb") as file:
        try:
            data = pkl.load(file)
            if len(data) < 18:
                print(f"⚠️ Skipping {model_file} - Unexpected structure")
                continue

            holdout_mask = data[0]
            l = data[4]
            sp_mean = data[6]
            sp_var = data[7]
            uid = 30
            model_type = data[10]
            cv_test = data[13]

            se_index = holdout_mask == 1
            llpd = np.mean(cv_test[se_index]) if isinstance(cv_test, np.ndarray) and np.any(se_index) else np.nan

            model_data.append([model_file, model_type, l, sp_mean, sp_var, llpd, uid])

        except Exception as e:
            print(f"❌ Error processing {model_file}: {e}")

# Build and display the DataFrame
columns = ['Filename', 'Model', 'Lambda', 'Mean SP', 'Variance SP', 'LLPD', 'UID']
df_models = pd.DataFrame(model_data, columns=columns).sort_values(by="LLPD", ascending=False)

from IPython.display import display
styled_df = df_models.head(10).style.background_gradient(cmap="viridis").set_properties(**{'text-align': 'center'})
display(styled_df)
# Out:
# ✅ Found 120 model files.
# <style type="text/css">
# #T_3d5ad_row0_col0, #T_3d5ad_row1_col0, #T_3d5ad_row2_col0, #T_3d5ad_row3_col0, #T_3d5ad_row4_col0, #T_3d5ad_row5_col0, #T_3d5ad_row6_col0, #T_3d5ad_row7_col0, #T_3d5ad_row8_col0, #T_3d5ad_row9_col0 {
#   text-align: center;
# }
# #T_3d5ad_row0_col1, #T_3d5ad_row4_col1, #T_3d5ad_row7_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3d5ad_row0_col2, #T_3d5ad_row0_col3, #T_3d5ad_row0_col4, #T_3d5ad_row0_col5, #T_3d5ad_row0_col6, #T_3d5ad_row1_col1, #T_3d5ad_row1_col2, #T_3d5ad_row1_col3, #T_3d5ad_row1_col4, #T_3d5ad_row1_col5, #T_3d5ad_row1_col6, #T_3d5ad_row2_col2, #T_3d5ad_row2_col3, #T_3d5ad_row2_col4, #T_3d5ad_row2_col5, #T_3d5ad_row2_col6, #T_3d5ad_row3_col1, #T_3d5ad_row3_col2, #T_3d5ad_row3_col3, #T_3d5ad_row3_col4, #T_3d5ad_row3_col5, #T_3d5ad_row3_col6, #T_3d5ad_row4_col2, #T_3d5ad_row4_col3, #T_3d5ad_row4_col4, #T_3d5ad_row4_col5, #T_3d5ad_row4_col6, #T_3d5ad_row5_col2, #T_3d5ad_row5_col3, #T_3d5ad_row5_col4, #T_3d5ad_row5_col5, #T_3d5ad_row5_col6, #T_3d5ad_row6_col2, #T_3d5ad_row6_col3, #T_3d5ad_row6_col4, #T_3d5ad_row6_col5, #T_3d5ad_row6_col6, #T_3d5ad_row7_col2, #T_3d5ad_row7_col3, #T_3d5ad_row7_col4, #T_3d5ad_row7_col5, #T_3d5ad_row7_col6, #T_3d5ad_row8_col2, #T_3d5ad_row8_col3, #T_3d5ad_row8_col4, #T_3d5ad_row8_col5, #T_3d5ad_row8_col6, #T_3d5ad_row9_col2, #T_3d5ad_row9_col3, #T_3d5ad_row9_col4, #T_3d5ad_row9_col5, #T_3d5ad_row9_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3d5ad_row2_col1 {
#   background-color: #90d743;
#   color: #000000;
#   text-align: center;
# }
# #T_3d5ad_row5_col1, #T_3d5ad_row6_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_3d5ad_row8_col1, #T_3d5ad_row9_col1 {
#   background-color: #fde725;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_3d5ad_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Filename</th>
#       <th class="col_heading level0 col1" >Model</th>
#       <th class="col_heading level0 col2" >Lambda</th>
#       <th class="col_heading level0 col3" >Mean SP</th>
#       <th class="col_heading level0 col4" >Variance SP</th>
#       <th class="col_heading level0 col5" >LLPD</th>
#       <th class="col_heading level0 col6" >UID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d5ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d5ad_row0_col0" class="data row0 col0" >../results/results_new_var_c/component/models/30_11_17_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_3d5ad_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_3d5ad_row0_col3" class="data row0 col3" >0.050383</td>
#       <td id="T_3d5ad_row0_col4" class="data row0 col4" >0.100000</td>
#       <td id="T_3d5ad_row0_col5" class="data row0 col5" >21.566982</td>
#       <td id="T_3d5ad_row0_col6" class="data row0 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d5ad_row1_col0" class="data row1 col0" >../results/results_new_var_c/component/models/30_8_13_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_3d5ad_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_3d5ad_row1_col3" class="data row1 col3" >0.050383</td>
#       <td id="T_3d5ad_row1_col4" class="data row1 col4" >0.100000</td>
#       <td id="T_3d5ad_row1_col5" class="data row1 col5" >21.566982</td>
#       <td id="T_3d5ad_row1_col6" class="data row1 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row2" class="row_heading level0 row2" >88</th>
#       <td id="T_3d5ad_row2_col0" class="data row2 col0" >../results/results_new_var_c/component/models/30_13_14_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_3d5ad_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_3d5ad_row2_col3" class="data row2 col3" >0.050383</td>
#       <td id="T_3d5ad_row2_col4" class="data row2 col4" >0.100000</td>
#       <td id="T_3d5ad_row2_col5" class="data row2 col5" >21.566982</td>
#       <td id="T_3d5ad_row2_col6" class="data row2 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row3" class="row_heading level0 row3" >87</th>
#       <td id="T_3d5ad_row3_col0" class="data row3 col0" >../results/results_new_var_c/component/models/30_8_6_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_3d5ad_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_3d5ad_row3_col3" class="data row3 col3" >0.050383</td>
#       <td id="T_3d5ad_row3_col4" class="data row3 col4" >0.100000</td>
#       <td id="T_3d5ad_row3_col5" class="data row3 col5" >21.566982</td>
#       <td id="T_3d5ad_row3_col6" class="data row3 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row4" class="row_heading level0 row4" >86</th>
#       <td id="T_3d5ad_row4_col0" class="data row4 col0" >../results/results_new_var_c/component/models/30_11_13_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_3d5ad_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_3d5ad_row4_col3" class="data row4 col3" >0.050383</td>
#       <td id="T_3d5ad_row4_col4" class="data row4 col4" >0.100000</td>
#       <td id="T_3d5ad_row4_col5" class="data row4 col5" >21.566982</td>
#       <td id="T_3d5ad_row4_col6" class="data row4 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row5" class="row_heading level0 row5" >85</th>
#       <td id="T_3d5ad_row5_col0" class="data row5 col0" >../results/results_new_var_c/component/models/30_10_15_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_3d5ad_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_3d5ad_row5_col3" class="data row5 col3" >0.050383</td>
#       <td id="T_3d5ad_row5_col4" class="data row5 col4" >0.100000</td>
#       <td id="T_3d5ad_row5_col5" class="data row5 col5" >21.566982</td>
#       <td id="T_3d5ad_row5_col6" class="data row5 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row6" class="row_heading level0 row6" >84</th>
#       <td id="T_3d5ad_row6_col0" class="data row6 col0" >../results/results_new_var_c/component/models/30_10_16_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_3d5ad_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_3d5ad_row6_col3" class="data row6 col3" >0.050383</td>
#       <td id="T_3d5ad_row6_col4" class="data row6 col4" >0.100000</td>
#       <td id="T_3d5ad_row6_col5" class="data row6 col5" >21.566982</td>
#       <td id="T_3d5ad_row6_col6" class="data row6 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row7" class="row_heading level0 row7" >83</th>
#       <td id="T_3d5ad_row7_col0" class="data row7 col0" >../results/results_new_var_c/component/models/30_11_11_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row7_col1" class="data row7 col1" >11</td>
#       <td id="T_3d5ad_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_3d5ad_row7_col3" class="data row7 col3" >0.050383</td>
#       <td id="T_3d5ad_row7_col4" class="data row7 col4" >0.100000</td>
#       <td id="T_3d5ad_row7_col5" class="data row7 col5" >21.566982</td>
#       <td id="T_3d5ad_row7_col6" class="data row7 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3d5ad_level0_row8" class="row_heading level0 row8" >82</th>
#       <td id="T_3d5ad_row8_col0" class="data row8 col0" >../results/results_new_var_c/component/models/30_14_16_model_nb_cvtest.pkl</td>
#       <td id="T_3d5ad_row8_col1" class="data row8 col1" >14</td>
#       <td id="T_3d5ad_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_3d5ad_row8_col3" class="data row8 col3" >0.050383</td>
#       <td id="T_3d5ad_row8_col4" class="data row8 col4" >0.100000</td>
#       <td id="T_3d5ad_row8_col5" class="data row8 col5"

# %%
import pickle 
for file in fname_o:
    print(f"Inspecting file: {os.path.relpath(file)}")
    try:
        with open(file, "rb") as f:
            data = pickle.load(f)
        
        # Check if the data is iterable (e.g., list, tuple, dict)
        if isinstance(data, (list, tuple)):
            print(f"File contains a {type(data).__name__} with {len(data)} elements.")
            for i, element in enumerate(data):
                print(f"  Element {i}: Type={type(element)}")
        elif isinstance(data, dict):
            print(f"File contains a dictionary with {len(data)} keys.")
            for key, value in data.items():
                print(f"  Key='{key}': Type={type(value)}")
        else:
            print(f"File contains a single object of type {type(data).__name__}.")
    except Exception as e:
        print(f"Error while reading {file}: {e}")
    print("-" * 50)
# Out:
# Inspecting file: ../results/results_new_var_c/component/models/30_11_17_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_13_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_3_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_7_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_16_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_20_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_19_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_12_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_1_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_3_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_5_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_5_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_18_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_13_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_14_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_18_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_20_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_8_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_1_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_12_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_18_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_12_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_4_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_10_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_10_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_8_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_17_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_15_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_11_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_20_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_15_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_9_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_18_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_1_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_19_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_8_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_5_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_19_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_10_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_15_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_8_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_13_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_10_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_1_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_3_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_4_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_6_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_16_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_2_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_20_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_16_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_2_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_14_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
# ...
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_7_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_2_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_16_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_8_5_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_7_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_11_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_4_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_7_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_10_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_10_3_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_14_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_17_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_20_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_7_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_11_12_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_12_2_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_1_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_13_11_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------
# Inspecting file: ../results/results_new_var_c/component/models/30_14_8_model_nb_cvtest.pkl
# File contains a list with 18 elements.
#   Element 0: Type=<class 'numpy.ndarray'>
#   Element 1: Type=<class 'int'>
#   Element 2: Type=<class 'int'>
#   Element 3: Type=<class 'int'>
#   Element 4: Type=<class 'int'>
#   Element 5: Type=<class 'int'>
#   Element 6: Type=<class 'float'>
#   Element 7: Type=<class 'float'>
#   Element 8: Type=<class 'float'>
#   Element 9: Type=<class 'int'>
#   Element 10: Type=<class 'int'>
#   Element 11: Type=<class 'numpy.ndarray'>
#   Element 12: Type=<class 'numpy.ndarray'>
#   Element 13: Type=<class 'numpy.ndarray'>
#   Element 14: Type=<class 'numpy.ndarray'>
#   Element 15: Type=<class 'numpy.ndarray'>
#   Element 16: Type=<class 'int'>
#   Element 17: Type=<class 'int'>
# --------------------------------------------------

# %%
# Extract model output and compute LLPD
out = {}

for i in range(len(fname_o)):
    if (i % 20) == 0:
        print(i)

    # Load the model file
    with open(fname_o[i], "rb") as file:
        [holdout_mask, Yte_sample, llpd, n_test, l, m_seed, sp_mean,
         sp_var, h_prop, uid, nsample_o, Yte_fit,
         cv_test, Y, muest, Yte_cv, Yte_lpmf, kl_comp] = pkl.load(file)

    se_index = holdout_mask == 1.

    # Compute LLPD
    temp_ll = cv_test[se_index]
    temp_ll = np.mean(temp_ll)

    # Extract mtype correctly
    filename = os.path.basename(fname_o[i])  # Extract only the filename
    filename_parts = filename.split('_')  # Split by '_'
    #print(filename_parts[1])

    if len(filename_parts) >= 3:
        mtype = int(filename_parts[1])  # Extract the second part (e.g., "0" from "30_0_10_model_nb_cvtest.pkl")
    else:
        raise ValueError(f"Unexpected filename format: {filename}")
    if len(filename_parts) >= 4:
        mtype = int(filename_parts[1])  # because filename is: mseed_mtype_uid_model_nb_cvtest.pkl
    else:
        raise ValueError(f"Unexpected filename format: {filename}")

    # Compute error
    error = np.mean(np.power(Y - muest, 2)[se_index])

    # Store results
    out[i] = [i, l, sp_mean, sp_var, temp_ll, uid, mtype] #[i, l, sp_mean, sp_var, temp_ll, uid, mtype]

print("Processing complete!")
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# Processing complete!

# %%
values = cv_test[se_index]
print("cv_test (holdout):", values)
print("np.any(np.isinf(values)):", np.any(np.isinf(values)))
print("np.mean(values):", np.mean(values))
# Out:
# cv_test (holdout): [-inf -inf -inf ... -inf -inf -inf]
# np.any(np.isinf(values)): True
# np.mean(values): -inf

# %%
print("Sample entry in 'out':", next(iter(out.values())))
# Out:
# Sample entry in 'out': [0, 100, 0.050383, 0.1, -inf, 6, 11]

# %%
print(df["llpd"].isna().sum())          # number of NaNs
print(np.isinf(df["llpd"]).sum())       # number of Infs
# Out:
# 40
# 80

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


# Convert dictionary to DataFrame
columns = ["Index", "l", "sp_mean", "sp_var", "llpd", "uid", "mtype"]
df = pd.DataFrame.from_dict(out, orient="index", columns=columns)

# Ensure `mtype` is an integer and properly categorized
df["mtype"] = df["mtype"].astype(int)
df["mtype"] = df["mtype"].astype("category")

# Group by mtype and aggregate mean + standard deviation
out_mean = df.groupby("mtype")["llpd"].mean().reset_index()
out_std = df.groupby("mtype")["llpd"].std().reset_index()

# Merge mean and std for full dataset
out_mean["std"] = out_std["llpd"]

# Now use the full dataset `df` for the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="mtype", y="llpd", data=df, palette="husl")

plt.xlabel("Model Type", fontsize=14)
plt.ylabel("LLPD", fontsize=14)
plt.title("LLPD Variation Across Different Models", fontsize=16)
plt.ylim(top=-3.25)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.2f}'))
plt.xticks(rotation=0)

plot_filename = os.path.join(figfol, "llpd_error_plot_filtered_uid30.png")
plt.savefig(plot_filename, dpi=400)
plt.show()
# Out:
# /dss/dsshome1/09/ra64nef3/.conda/envs/vim/lib/python3.7/site-packages/numpy/lib/function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /dss/dsshome1/09/ra64nef3/.conda/envs/vim/lib/python3.7/site-packages/numpy/lib/function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /dss/dsshome1/09/ra64nef3/.conda/envs/vim/lib/python3.7/site-packages/numpy/lib/function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /dss/dsshome1/09/ra64nef3/.conda/envs/vim/lib/python3.7/site-packages/numpy/lib/function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
import glob
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# Step 1: Load existing results into `out`
# Assuming `out` already exists as a dictionary from previously loaded mtypes
if data == "original": 
    # Step 2: Load additional mtype=6 results from different folder
    new_path = "../results/results_old_nc/component/models/*model_nb_cvtest.pkl"
    new_files = glob.glob(new_path)
elif data == "new": 
    new_path = "../results/results_new_nc/component/models/*model_nb_cvtest.pkl"
    new_files = glob.glob(new_path)

# Continue index from the existing max index
start_idx = max(out.keys()) + 1 if out else 0

for idx, file in enumerate(new_files):
    with open(file, "rb") as f:
        content = pickle.load(f)

        try:
            holdout_mask, _, _, _, l, m_seed, sp_mean, sp_var, h_prop, uid, mtype, \
            Yte_fit, cv_test, Y, muest, Yte_cv, _, _ = content

            llpd = cv_test.sum() / holdout_mask.sum()

            out[start_idx + idx] = [start_idx + idx, l, sp_mean, sp_var, llpd, uid, 6]  # manually set mtype to 6

        except Exception as e:
            print(f"❌ Could not load {file}: {e}")



# Convert dictionary to DataFrame
columns = ["Index", "l", "sp_mean", "sp_var", "llpd", "uid", "mtype"]
df = pd.DataFrame.from_dict(out, orient="index", columns=columns)

# Ensure `mtype` is an integer and properly categorized
df["mtype"] = df["mtype"].astype(int)
df["mtype"] = df["mtype"].astype("category")

# Group by mtype and aggregate mean + standard deviation
out_mean = df.groupby("mtype")["llpd"].mean().reset_index()
out_std = df.groupby("mtype")["llpd"].std().reset_index()

# Merge mean and std for full dataset
out_mean["std"] = out_std["llpd"]

# Now use the full dataset `df` for the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="mtype", y="llpd", data=df, palette="husl")

# Labels and title
plt.xlabel("Model Type", fontsize=14)
plt.ylabel("LLPD", fontsize=14)
plt.title("LLPD Variation Across Different Models", fontsize=16)

# Set y-axis limit (upper bound at -3.25)
plt.ylim(bottom=None, top=-3.25)

# Format y-axis to two decimal places
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.2f}'))

# Show the plot
plt.xticks(rotation=0)
plot_filename = os.path.join(figfol, "llpd_error_plot_all_mtype_6.png")
plt.savefig(plot_filename, dpi=400)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /dss/lxclscratch/09/ra64nef3/ra64nef3/ipykernel_122021/3200257982.py in <module>
#      18 start_idx = max(out.keys()) + 1 if out else 0
#      19
# ---> 20 for idx, file in enumerate(new_files):
#      21     with open(file, "rb") as f:
#      22         content = pickle.load(f)
#
# NameError: name 'new_files' is not defined

# %%
import glob
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load old model results
fname_o = glob.glob('../results/results_old_nc/component/models/*model_nb_cvtest.pkl')

old_results = []

for fname in fname_o:
    with open(fname, "rb") as f:
        try:
            loaded_data = pickle.load(f)
            # If the file contains a list, iterate directly
            for entry in loaded_data:
                entry["mtype"] = 6  # Assign new model type
                old_results.append(entry)
        except Exception as e:
            print(f"Could not load {fname}: {e}")

# Define column names if needed
columns = ["Index", "l", "sp_mean", "sp_var", "llpd", "uid", "mtype"]

# Convert to DataFrame
df_old = pd.DataFrame(old_results, columns=columns)

# Combine with your original df
df_combined = pd.concat([df, df_old], ignore_index=True)

# Ensure `mtype` is categorical
df_combined["mtype"] = df_combined["mtype"].astype(int)
df_combined["mtype"] = df_combined["mtype"].astype("category")

# Plot updated boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="mtype", y="llpd", data=df_combined, palette="husl")

# Labels and title
plt.xlabel("Model Type", fontsize=14)
plt.ylabel("LLPD", fontsize=14)
plt.title("LLPD Variation Across Different Models (Including Old Model Type)", fontsize=16)
plt.ylim(bottom=None, top=-3.25)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.2f}'))
plt.xticks(rotation=0)

# Save and show
plot_filename = os.path.join(figfol, "llpd_error_plot_all_mtype_with_old.png")
plt.savefig(plot_filename, dpi=400)
plt.show()
# Out:
# Could not load ../results/results_old_nc/component/models/30_6_0_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_18_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_14_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_3_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_13_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_16_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_10_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_2_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_15_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_1_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_7_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_4_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_8_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_19_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_17_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_5_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_9_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_11_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_12_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Could not load ../results/results_old_nc/component/models/30_6_6_model_nb_cvtest.pkl: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
out = pkl.load(open('comparison_model', "rb"))
print(type(out))  # Check if it's a dictionary or list
print(len(out))   # Check number of elements
print(out[0])     # Print one entry to inspect its structure
# Out:
# <class 'dict'>
# 120
# [0, 100, 0.06059627021136009, 0.0408163265306122, -3.3357373475427203, 30, 0]

# %%
out = pd.DataFrame.from_dict(out, orient='index')
print(out.shape)  # Check if the shape matches (rows, columns)
# Out:
# (120, 7)

# %%
# Load the data
out = pkl.load(open('comparison_model', "rb"))

# Convert the dictionary to a DataFrame more carefully
# Method 1: Try converting dict values to DataFrame directly
out_df = pd.DataFrame.from_dict(out, orient='index', columns=['Index','rank','lambda','upsilon','llpd','uid','Model'])

# If Method 1 doesn't work, try Method 2:
# First convert dict to list of lists
data_list = [value for value in out.values()]
out_df = pd.DataFrame(data_list, columns=['Index','rank','lambda','upsilon','llpd','uid','Model'])

# Display the first 20 rows
print(out_df.head(20))
# Out:
#     Index  rank    lambda   upsilon      llpd  uid  Model
# 0       0   100  0.060596  0.040816 -3.335737   30      0
# 1       1   100  0.060596  0.040816 -3.394061   30      4
# 2       2   100  0.060596  0.040816 -3.351756   30      0
# 3       3   100  0.060596  0.040816 -3.371079   30      1
# 4       4   100  0.060596  0.040816 -3.317078   30      0
# 5       5   100  0.060596  0.040816 -3.365383   30      2
# 6       6   100  0.060596  0.040816 -3.336005   30      0
# 7       7   100  0.060596  0.040816 -3.392644   30      2
# 8       8   100  0.060596  0.040816 -3.346224   30      5
# 9       9   100  0.060596  0.040816 -3.319387   30      5
# 10     10   100  0.060596  0.040816 -3.376695   30      0
# 11     11   100  0.060596  0.040816 -3.421014   30      4
# 12     12   100  0.060596  0.040816 -3.345962   30      5
# 13     13   100  0.060596  0.040816 -3.378402   30      4
# 14     14   100  0.060596  0.040816 -3.350975   30      1
# 15     15   100  0.060596  0.040816 -3.364605   30      2
# 16     16   100  0.060596  0.040816 -3.325935   30      5
# 17     17   100  0.060596  0.040816 -3.328903   30      0
# 18     18   100  0.060596  0.040816 -3.374032   30      2
# 19     19   100  0.060596  0.040816 -3.339409   30      0

# %% [markdown]
# <font color=blue>**Our analysis suggest that the model 0, i.e., MEM is best with highest out of sample LLPD$_o$.** </font>

# %%
# First, convert the dictionary to a DataFrame
out_df = pd.DataFrame.from_dict(out, orient='index')

# Now rename the columns
out_df.columns = ['Index', 'rank', 'lambda', 'upsilon', 'llpd', 'uid', 'Model']

# Now we can perform the groupby operation
results = out_df.groupby(['Model'], as_index=False).agg({'llpd': ['mean', 'std']})

print(results)
# Out:
#   Model      llpd
#              mean       std
# 0     0 -3.336061  0.019514
# 1     1 -3.341048  0.020001
# 2     2 -3.358865  0.022243
# 3     3 -3.356661  0.021063
# 4     4 -3.403350  0.017467
# 5     5 -3.339607  0.018942

# %%
# Convert dictionary to DataFrame
out_df = pd.DataFrame.from_dict(out, orient='index')

# Rename columns
out_df.columns = ['Index', 'rank', 'lambda', 'upsilon', 'llpd', 'uid', 'Model']

# Now perform the groupby and transform to get the LaTeX output
out_sub = out_df.groupby(['Model'], as_index=False).mean()[['Model','llpd']].transpose()

# Print LaTeX formatted table
print(out_sub.to_latex(float_format="%.4f", bold_rows=True))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &       0 &       1 &       2 &       3 &       4 &       5 \\
# \midrule
# \textbf{Model} &  0.0000 &  1.0000 &  2.0000 &  3.0000 &  4.0000 &  5.0000 \\
# \textbf{llpd } & -3.3361 & -3.3410 & -3.3589 & -3.3567 & -3.4033 & -3.3396 \\
# \bottomrule
# \end{tabular}

# %%
l,m_seed,sp_mean, sp_var
# Out:
# (100, 18, 0.06059627021136009, 0.0408163265306122)

# %%
# Convert dictionary to DataFrame
out_df = pd.DataFrame.from_dict(out, orient='index')
out_df.columns = ['Index', 'rank', 'lambda', 'upsilon', 'llpd', 'uid', 'Model']

# Sort by LLPD in descending order (highest first) and get the first row
best_model = out_df.sort_values('llpd', ascending=False).iloc[0]

print("Best Model Configuration:")
print(f"Model Type (mtype): {int(best_model['Model'])}")
print(f"Model Seed (mseed): {int(best_model['Index'])}")
print(f"LLPD Score: {best_model['llpd']:.6f}")
print(f"Other parameters:")
print(f"  Lambda: {best_model['lambda']}")
print(f"  Upsilon: {best_model['upsilon']}")
print(f"  Rank: {int(best_model['rank'])}")
# Out:
# Best Model Configuration:
# Model Type (mtype): 5
# Model Seed (mseed): 86
# LLPD Score: -3.304545
# Other parameters:
#   Lambda: 0.06059627021136009
#   Upsilon: 0.0408163265306122
#   Rank: 100

# %%
# Given values
index = int(best_model['Index']) # your best model's index
mtype = int(best_model['Model'])  # your best model's type
uid = 30    # from the data

# Calculate actual mseed (0-19)
mseed = index % 20  # This gives us which run number it was within its mtype group

print(f"For index {index}:")
print(f"Model Type (mtype): {mtype}")
print(f"Model Seed (mseed): {mseed}")
print(f"UID: {uid}")
print(f"\nExpected filename: {uid}_{mtype}_{mseed}_model_nb_cvtest.pkl")
# Out:
# For index 86:
# Model Type (mtype): 5
# Model Seed (mseed): 6
# UID: 30
#
# Expected filename: 30_5_6_model_nb_cvtest.pkl

# %%
# Load and inspect comparison_model file
import pickle as pkl

# Load the data
with open('comparison_model', 'rb') as f:
    data = pkl.load(f)

# Print general information
print("Type of data:", type(data))
print("Number of entries:", len(data))
print("\nStructure of each entry:")
for i in range(3):  # Show first 3 entries
    print(f"\nEntry {i}:")
    print(f"Raw data: {data[i]}")
    print("Interpreted as:")
    print(f"  Index: {data[i][0]}")
    print(f"  Rank: {data[i][1]}")
    print(f"  Lambda: {data[i][2]}")
    print(f"  Upsilon: {data[i][3]}")
    print(f"  LLPD: {data[i][4]}")
    print(f"  UID: {data[i][5]}")
    print(f"  Model Type: {data[i][6]}")

print("\nUnique Model Types:", sorted(set(data[i][6] for i in range(len(data)))))
print("Unique UIDs:", sorted(set(data[i][5] for i in range(len(data)))))
# Out:
# Type of data: <class 'dict'>
# Number of entries: 120
#
# Structure of each entry:
#
# Entry 0:
# Raw data: [0, 100, 0.06059627021136009, 0.0408163265306122, -3.3357373475427203, 30, 0]
# Interpreted as:
#   Index: 0
#   Rank: 100
#   Lambda: 0.06059627021136009
#   Upsilon: 0.0408163265306122
#   LLPD: -3.3357373475427203
#   UID: 30
#   Model Type: 0
#
# Entry 1:
# Raw data: [1, 100, 0.06059627021136009, 0.0408163265306122, -3.3940612259344527, 30, 4]
# Interpreted as:
#   Index: 1
#   Rank: 100
#   Lambda: 0.06059627021136009
#   Upsilon: 0.0408163265306122
#   LLPD: -3.3940612259344527
#   UID: 30
#   Model Type: 4
#
# Entry 2:
# Raw data: [2, 100, 0.06059627021136009, 0.0408163265306122, -3.351755606155532, 30, 0]
# Interpreted as:
#   Index: 2
#   Rank: 100
#   Lambda: 0.06059627021136009
#   Upsilon: 0.0408163265306122
#   LLPD: -3.351755606155532
#   UID: 30
#   Model Type: 0
#
# Unique Model Types: [0, 1, 2, 3, 4, 5]
# Unique UIDs: [30]
